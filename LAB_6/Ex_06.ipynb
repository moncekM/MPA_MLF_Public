# %% [markdown]
# # MPA-MLF, Lab 6 - Feedforward Neural Networks with regularization techniques and hyperparameter tunning

# %% [markdown]
# ## Exercise 1 - Classification of an images

# %% [markdown]
# The goal of this task will be to create Multi-layer perceptron model, that is able to recognize the  CIFAR10 dataset (https://www.cs.toronto.edu/~kriz/cifar.html). The CIFAR10 dataset consist of 60000 images with resolution of 32x32 pixels. There are 10 classes in total - *airplane*, *automobile*, *bird*, *cat*, *deer*, *dog*, *frog*, *horse*, *ship*, *truck*

# %% [markdown]
# These is an example of the dataset:

# %% [markdown]
# ![cifar10.png](data:image/png;base64,...)

# %% [markdown]
# ### 0. Import libraries

# %%
import keras
import matplotlib.pyplot as plt
import matplotlib
import numpy as np


font = {'weight' : 'bold',
        'size'   : 12}

# %% [markdown]
# ### 1. Load the Dataset
# The dataset is already a part of the Keras library, so we can quickly load it using the following command

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

# %% [markdown]
# The following numbered labels represent the labels in the dataset:

# %%
labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

# %% [markdown]
# ### 2. Data Examination

# %% [markdown]
# Fistly, lets have a look and the couple of images we have,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels_encoded = y_data[selected_ind]
  selected_labels = [labels[x[0]] for x in selected_labels_encoded]

  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img)

  for id_label, label in enumerate(selected_labels):
    plt.text((32/2) + 32*id_label - len(label), 32*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %%
#check the shape of image dataset

X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# In our dataset, we have 60000 images with 32x32 resolution. Each image has three channels (R, G, B). We have 50000 images for training and 10000 images for testing. Each channel for each image has values from 0 - 255, where each number represents the pixel intensity.
# With the combination of intensities of R, G and B, you can display up to 16,777,216 different colours (256^3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here you can display each channel separately:

# %%
def display_channels_separately(image: np.array) -> None:

  plt.figure()
  fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(10, 5))


  axs[0].imshow(image[:,:,0],cmap='Reds')
  axs[1].imshow(image[:,:,1],cmap='Blues')
  axs[2].imshow(image[:,:,2],cmap='Greens')

  axs[3].imshow(image)

  plt.show()

# %%
display_channels_separately(X_train[0])

# %% [markdown]
# ### 3. Preprocessing of the images

# %% [markdown]
# For machine learning purposes, we have to preprocess our images. Firstly we need to scale our images, to scale intensity values from 0-1 (min-max scaling)

# %%
X_train_scaled = X_train.astype('float32') / 255.0

# %% [markdown]
# We need to one-hot-encode the labels in our ground truth variable as our second preprocessing.

# %%
y_train_encoded = keras.utils.to_categorical(y_train, num_classes=10)

# %% [markdown]
# ### 4. Define the model architecture

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(32, 32, 3)))
model.add(keras.layers.Dense(256))
model.add(keras.layers.LeakyReLU(alpha=0.1))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dropout(0.3)) 
model.add(keras.layers.Dense(128))
model.add(keras.layers.LeakyReLU(alpha=0.1))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(256))
model.add(keras.layers.LeakyReLU(alpha=0.1))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dense(128))
model.add(keras.layers.LeakyReLU(alpha=0.1))
model.add(keras.layers.BatchNormalization())  
model.add(keras.layers.Dense(512))
model.add(keras.layers.LeakyReLU(alpha=0.1))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(10, activation='softmax'))

# %% [markdown]
# We will define *the Sequential* model as in our last exercise. This time we will use a different approach to determine the input layers. Instead of specifying the *input_dim* parameter in our first hidden layer, we will create a **Flatten** layer that takes our 32x32x3 image and reshapes it into 1x3072.
#
# We will specify ten neurons in our output layer because we have 10 possible outputs and a **softmax** activation function that returns us a probability distribution over the classes. The class with the highest probability is typically chosen as the predicted class for a given input.

# %% [markdown]
# Check the description of our model:

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_6 (Flatten)             │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 256)            │       786,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_10 (LeakyReLU)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_25 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_11 (LeakyReLU)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_26 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_12 (LeakyReLU)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_13 (LeakyReLU)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_14 (LeakyReLU)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 961,802 (3.67 MB)
#  Trainable params: 959,242 (3.66 MB)
#  Non-trainable params: 2,560 (10.00 KB)

# %% [markdown]
# The next step is to compile our model, we will use *categorical_crossentropy* as a loss function, *stochastic gradient descend* as an optimisation and we will be checking *the accuracy* metric.

# %% [markdown]
# ### 5. Train the model

# %%
optimizer = keras.optimizers.Adamax   (learning_rate = 0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# Our model will be trained in the same way as in our last pc_labs,

# %%
history = model.fit(X_train_scaled, y_train_encoded, epochs=200 , batch_size=32   , validation_split = 0.2)
# Out:
# Epoch 1/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.2056 - loss: 2.4783 - val_accuracy: 0.3359 - val_loss: 1.8616
# Epoch 2/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.2966 - loss: 1.9938 - val_accuracy: 0.3643 - val_loss: 1.7831
# Epoch 3/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.3379 - loss: 1.8444 - val_accuracy: 0.4054 - val_loss: 1.6775
# Epoch 4/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.3722 - loss: 1.7468 - val_accuracy: 0.4175 - val_loss: 1.6351
# Epoch 5/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.3926 - loss: 1.6933 - val_accuracy: 0.4330 - val_loss: 1.5886
# Epoch 6/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4056 - loss: 1.6650 - val_accuracy: 0.4302 - val_loss: 1.5952
# Epoch 7/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4169 - loss: 1.6341 - val_accuracy: 0.4524 - val_loss: 1.5567
# Epoch 8/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4218 - loss: 1.6162 - val_accuracy: 0.4391 - val_loss: 1.5598
# Epoch 9/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4344 - loss: 1.5827 - val_accuracy: 0.4535 - val_loss: 1.5289
# Epoch 10/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4330 - loss: 1.5894 - val_accuracy: 0.4425 - val_loss: 1.5549
# Epoch 11/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4410 - loss: 1.5680 - val_accuracy: 0.4583 - val_loss: 1.5158
# Epoch 12/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4443 - loss: 1.5540 - val_accuracy: 0.4415 - val_loss: 1.5534
# Epoch 13/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.4524 - loss: 1.5281 - val_accuracy: 0.4765 - val_loss: 1.4645
# Epoch 14/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4563 - loss: 1.5250 - val_accuracy: 0.4763 - val_loss: 1.4761
# Epoch 15/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.4682 - loss: 1.5078 - val_accuracy: 0.4713 - val_loss: 1.4722
# Epoch 16/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4577 - loss: 1.5152 - val_accuracy: 0.4875 - val_loss: 1.4410
# Epoch 17/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.4721 - loss: 1.4919 - val_accuracy: 0.4702 - val_loss: 1.4764
# Epoch 18/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4687 - loss: 1.4965 - val_accuracy: 0.4898 - val_loss: 1.4591
# Epoch 19/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.4668 - loss: 1.4961 - val_accuracy: 0.4864 - val_loss: 1.4304
# Epoch 20/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.4762 - loss: 1.4734 - val_accuracy: 0.5016 - val_loss: 1.4169
# Epoch 21/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.4755 - loss: 1.4608 - val_accuracy: 0.4904 - val_loss: 1.4332
# Epoch 22/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.4770 - loss: 1.4634 - val_accuracy: 0.4970 - val_loss: 1.4209
# Epoch 23/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4791 - loss: 1.4657 - val_accuracy: 0.4955 - val_loss: 1.4178
# Epoch 24/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4805 - loss: 1.4529 - val_accuracy: 0.4940 - val_loss: 1.4173
# Epoch 25/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.4843 - loss: 1.4423 - val_accuracy: 0.4931 - val_loss: 1.4291
# Epoch 26/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4901 - loss: 1.4349 - val_accuracy: 0.4988 - val_loss: 1.4134
# Epoch 27/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4905 - loss: 1.4331 - val_accuracy: 0.4963 - val_loss: 1.4069
# Epoch 28/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4956 - loss: 1.4290 - val_accuracy: 0.5074 - val_loss: 1.3879
# Epoch 29/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4974 - loss: 1.4253 - val_accuracy: 0.4994 - val_loss: 1.3983
# Epoch 30/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4964 - loss: 1.4110 - val_accuracy: 0.4971 - val_loss: 1.4180
# Epoch 31/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4962 - loss: 1.4104 - val_accuracy: 0.4970 - val_loss: 1.4335
# Epoch 32/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4973 - loss: 1.4082 - val_accuracy: 0.5001 - val_loss: 1.3972
# Epoch 33/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5027 - loss: 1.3963 - val_accuracy: 0.4901 - val_loss: 1.4482
# Epoch 34/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.5025 - loss: 1.4045 - val_accuracy: 0.4984 - val_loss: 1.4034
# Epoch 35/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4982 - loss: 1.4000 - val_accuracy: 0.4956 - val_loss: 1.4164
# Epoch 36/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5073 - loss: 1.3867 - val_accuracy: 0.5064 - val_loss: 1.3981
# Epoch 37/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.5043 - loss: 1.3932 - val_accuracy: 0.5045 - val_loss: 1.3889
# Epoch 38/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5025 - loss: 1.3905 - val_accuracy: 0.5091 - val_loss: 1.3750
# Epoch 39/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5057 - loss: 1.3862 - val_accuracy: 0.5013 - val_loss: 1.4214
# Epoch 40/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5100 - loss: 1.3784 - val_accuracy: 0.5112 - val_loss: 1.3841
# Epoch 41/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5162 - loss: 1.3704 - val_accuracy: 0.5126 - val_loss: 1.3811
# Epoch 42/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5152 - loss: 1.3753 - val_accuracy: 0.5059 - val_loss: 1.3873
# Epoch 43/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5144 - loss: 1.3661 - val_accuracy: 0.5086 - val_loss: 1.3793
# Epoch 44/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5112 - loss: 1.3705 - val_accuracy: 0.5160 - val_loss: 1.3740
# Epoch 45/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5123 - loss: 1.3663 - val_accuracy: 0.5192 - val_loss: 1.3689
# Epoch 46/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5185 - loss: 1.3624 - val_accuracy: 0.5169 - val_loss: 1.3723
# Epoch 47/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5212 - loss: 1.3561 - val_accuracy: 0.5212 - val_loss: 1.3593
# Epoch 48/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5150 - loss: 1.3553 - val_accuracy: 0.5092 - val_loss: 1.3968
# Epoch 49/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5225 - loss: 1.3547 - val_accuracy: 0.5116 - val_loss: 1.3861
# Epoch 50/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5233 - loss: 1.3512 - val_accuracy: 0.5128 - val_loss: 1.3726
# Epoch 51/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5199 - loss: 1.3511 - val_accuracy: 0.5026 - val_loss: 1.3980
# Epoch 52/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5196 - loss: 1.3470 - val_accuracy: 0.5147 - val_loss: 1.3688
# Epoch 53/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5233 - loss: 1.3384 - val_accuracy: 0.5151 - val_loss: 1.3747
# Epoch 54/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5277 - loss: 1.3351 - val_accuracy: 0.5188 - val_loss: 1.3608
# Epoch 55/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5246 - loss: 1.3445 - val_accuracy: 0.5190 - val_loss: 1.3621
# Epoch 56/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5247 - loss: 1.3259 - val_accuracy: 0.5205 - val_loss: 1.3601
# Epoch 57/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5285 - loss: 1.3239 - val_accuracy: 0.5184 - val_loss: 1.3724
# Epoch 58/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5308 - loss: 1.3233 - val_accuracy: 0.5192 - val_loss: 1.3573
# Epoch 59/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5244 - loss: 1.3304 - val_accuracy: 0.5060 - val_loss: 1.3758
# Epoch 60/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5272 - loss: 1.3230 - val_accuracy: 0.5169 - val_loss: 1.3645
# Epoch 61/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5283 - loss: 1.3241 - val_accuracy: 0.5233 - val_loss: 1.3528
# Epoch 62/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5367 - loss: 1.3091 - val_accuracy: 0.5188 - val_loss: 1.3569
# Epoch 63/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5397 - loss: 1.2990 - val_accuracy: 0.5085 - val_loss: 1.3878
# Epoch 64/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5345 - loss: 1.3020 - val_accuracy: 0.5253 - val_loss: 1.3456
# Epoch 65/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5350 - loss: 1.2934 - val_accuracy: 0.5085 - val_loss: 1.3903
# Epoch 66/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5318 - loss: 1.3054 - val_accuracy: 0.5311 - val_loss: 1.3274
# Epoch 67/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5370 - loss: 1.3106 - val_accuracy: 0.5161 - val_loss: 1.3599
# Epoch 68/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5382 - loss: 1.2971 - val_accuracy: 0.5199 - val_loss: 1.3581
# Epoch 69/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5383 - loss: 1.2990 - val_accuracy: 0.5288 - val_loss: 1.3320
# Epoch 70/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5433 - loss: 1.2842 - val_accuracy: 0.5312 - val_loss: 1.3302
# Epoch 71/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5399 - loss: 1.2931 - val_accuracy: 0.5255 - val_loss: 1.3478
# Epoch 72/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5475 - loss: 1.2811 - val_accuracy: 0.5320 - val_loss: 1.3251
# Epoch 73/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5440 - loss: 1.2810 - val_accuracy: 0.5258 - val_loss: 1.3391
# Epoch 74/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5449 - loss: 1.2752 - val_accuracy: 0.5188 - val_loss: 1.3455
# Epoch 75/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5489 - loss: 1.2767 - val_accuracy: 0.5158 - val_loss: 1.3789
# Epoch 76/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5402 - loss: 1.2929 - val_accuracy: 0.5348 - val_loss: 1.3292
# Epoch 77/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5448 - loss: 1.2737 - val_accuracy: 0.5263 - val_loss: 1.3498
# Epoch 78/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5510 - loss: 1.2710 - val_accuracy: 0.5196 - val_loss: 1.3786
# Epoch 79/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5501 - loss: 1.2681 - val_accuracy: 0.5228 - val_loss: 1.3548
# Epoch 80/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5532 - loss: 1.2724 - val_accuracy: 0.5270 - val_loss: 1.3544
# Epoch 81/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5477 - loss: 1.2727 - val_accuracy: 0.5246 - val_loss: 1.3471
# Epoch 82/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5509 - loss: 1.2643 - val_accuracy: 0.5277 - val_loss: 1.3294
# Epoch 83/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5490 - loss: 1.2682 - val_accuracy: 0.5334 - val_loss: 1.3259
# Epoch 84/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5531 - loss: 1.2553 - val_accuracy: 0.5263 - val_loss: 1.3295
# Epoch 85/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5529 - loss: 1.2571 - val_accuracy: 0.5375 - val_loss: 1.3154
# Epoch 86/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5513 - loss: 1.2667 - val_accuracy: 0.5270 - val_loss: 1.3538
# Epoch 87/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5516 - loss: 1.2663 - val_accuracy: 0.5317 - val_loss: 1.3100
# Epoch 88/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5588 - loss: 1.2418 - val_accuracy: 0.5430 - val_loss: 1.2960
# Epoch 89/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5595 - loss: 1.2392 - val_accuracy: 0.5236 - val_loss: 1.3613
# Epoch 90/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5557 - loss: 1.2511 - val_accuracy: 0.5248 - val_loss: 1.3466
# Epoch 91/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5584 - loss: 1.2514 - val_accuracy: 0.5419 - val_loss: 1.3091
# Epoch 92/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5493 - loss: 1.2600 - val_accuracy: 0.5261 - val_loss: 1.3244
# Epoch 93/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5559 - loss: 1.2507 - val_accuracy: 0.5310 - val_loss: 1.3257
# Epoch 94/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5516 - loss: 1.2517 - val_accuracy: 0.5346 - val_loss: 1.3259
# Epoch 95/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5562 - loss: 1.2477 - val_accuracy: 0.5339 - val_loss: 1.3284
# Epoch 96/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5567 - loss: 1.2408 - val_accuracy: 0.5240 - val_loss: 1.3627
# Epoch 97/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5626 - loss: 1.2376 - val_accuracy: 0.5311 - val_loss: 1.3428
# Epoch 98/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5555 - loss: 1.2484 - val_accuracy: 0.5251 - val_loss: 1.3463
# Epoch 99/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5589 - loss: 1.2377 - val_accuracy: 0.5307 - val_loss: 1.3389
# Epoch 100/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5603 - loss: 1.2317 - val_accuracy: 0.5330 - val_loss: 1.3199
# Epoch 101/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5593 - loss: 1.2293 - val_accuracy: 0.5399 - val_loss: 1.3070
# Epoch 102/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5625 - loss: 1.2333 - val_accuracy: 0.5452 - val_loss: 1.3116
# Epoch 103/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5682 - loss: 1.2253 - val_accuracy: 0.5321 - val_loss: 1.3344
# Epoch 104/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5652 - loss: 1.2246 - val_accuracy: 0.5366 - val_loss: 1.3113
# Epoch 105/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5661 - loss: 1.2228 - val_accuracy: 0.5252 - val_loss: 1.3480
# Epoch 106/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5632 - loss: 1.2283 - val_accuracy: 0.5296 - val_loss: 1.3191
# Epoch 107/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5666 - loss: 1.2242 - val_accuracy: 0.5313 - val_loss: 1.3356
# Epoch 108/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5688 - loss: 1.2206 - val_accuracy: 0.5301 - val_loss: 1.3326
# Epoch 109/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5653 - loss: 1.2171 - val_accuracy: 0.5352 - val_loss: 1.3189
# Epoch 110/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5643 - loss: 1.2193 - val_accuracy: 0.5268 - val_loss: 1.3441
# Epoch 111/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5660 - loss: 1.2107 - val_accuracy: 0.5364 - val_loss: 1.3118
# Epoch 112/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5735 - loss: 1.2050 - val_accuracy: 0.5339 - val_loss: 1.3326
# Epoch 113/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5655 - loss: 1.2150 - val_accuracy: 0.5282 - val_loss: 1.3373
# Epoch 114/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5686 - loss: 1.2106 - val_accuracy: 0.5262 - val_loss: 1.3365
# Epoch 115/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5665 - loss: 1.2189 - val_accuracy: 0.5421 - val_loss: 1.3158
# Epoch 116/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5727 - loss: 1.2116 - val_accuracy: 0.5419 - val_loss: 1.3095
# Epoch 117/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5742 - loss: 1.1993 - val_accuracy: 0.5356 - val_loss: 1.3282
# Epoch 118/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5720 - loss: 1.2085 - val_accuracy: 0.5372 - val_loss: 1.3279
# Epoch 119/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5701 - loss: 1.2065 - val_accuracy: 0.5376 - val_loss: 1.3245
# Epoch 120/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5749 - loss: 1.1922 - val_accuracy: 0.5485 - val_loss: 1.2959
# Epoch 121/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5757 - loss: 1.1953 - val_accuracy: 0.5372 - val_loss: 1.3150
# Epoch 122/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5780 - loss: 1.1892 - val_accuracy: 0.5353 - val_loss: 1.3275
# Epoch 123/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5703 - loss: 1.1996 - val_accuracy: 0.5457 - val_loss: 1.2928
# Epoch 124/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5779 - loss: 1.1930 - val_accuracy: 0.5389 - val_loss: 1.3127
# Epoch 125/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5762 - loss: 1.1963 - val_accuracy: 0.5334 - val_loss: 1.3148
# Epoch 126/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5706 - loss: 1.1992 - val_accuracy: 0.5380 - val_loss: 1.3116
# Epoch 127/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5736 - loss: 1.1912 - val_accuracy: 0.5297 - val_loss: 1.3311
# Epoch 128/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5779 - loss: 1.1899 - val_accuracy: 0.5384 - val_loss: 1.3125
# Epoch 129/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5732 - loss: 1.1999 - val_accuracy: 0.5376 - val_loss: 1.3096
# Epoch 130/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5821 - loss: 1.1787 - val_accuracy: 0.5454 - val_loss: 1.2975
# Epoch 131/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5821 - loss: 1.1768 - val_accuracy: 0.5450 - val_loss: 1.3037
# Epoch 132/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5817 - loss: 1.1761 - val_accuracy: 0.5341 - val_loss: 1.3242
# Epoch 133/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5816 - loss: 1.1802 - val_accuracy: 0.5407 - val_loss: 1.3092
# Epoch 134/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5890 - loss: 1.1688 - val_accuracy: 0.5425 - val_loss: 1.2993
# Epoch 135/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5829 - loss: 1.1673 - val_accuracy: 0.5349 - val_loss: 1.3333
# Epoch 136/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5838 - loss: 1.1683 - val_accuracy: 0.5430 - val_loss: 1.3063
# Epoch 137/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5827 - loss: 1.1739 - val_accuracy: 0.5400 - val_loss: 1.3309
# Epoch 138/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5786 - loss: 1.1822 - val_accuracy: 0.5358 - val_loss: 1.3316
# Epoch 139/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5893 - loss: 1.1580 - val_accuracy: 0.5439 - val_loss: 1.2994
# Epoch 140/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5823 - loss: 1.1683 - val_accuracy: 0.5424 - val_loss: 1.3073
# Epoch 141/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5882 - loss: 1.1673 - val_accuracy: 0.5486 - val_loss: 1.3004
# Epoch 142/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5825 - loss: 1.1709 - val_accuracy: 0.5309 - val_loss: 1.3387
# Epoch 143/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5886 - loss: 1.1632 - val_accuracy: 0.5460 - val_loss: 1.2867
# Epoch 144/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5818 - loss: 1.1749 - val_accuracy: 0.5468 - val_loss: 1.2999
# Epoch 145/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5834 - loss: 1.1724 - val_accuracy: 0.5358 - val_loss: 1.3272
# Epoch 146/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5815 - loss: 1.1727 - val_accuracy: 0.5393 - val_loss: 1.3240
# Epoch 147/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5822 - loss: 1.1746 - val_accuracy: 0.5278 - val_loss: 1.3421
# Epoch 148/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5869 - loss: 1.1643 - val_accuracy: 0.5386 - val_loss: 1.3314
# Epoch 149/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5829 - loss: 1.1681 - val_accuracy: 0.5392 - val_loss: 1.3040
# Epoch 150/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5870 - loss: 1.1591 - val_accuracy: 0.5327 - val_loss: 1.3174
# Epoch 151/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5870 - loss: 1.1569 - val_accuracy: 0.5314 - val_loss: 1.3234
# Epoch 152/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5882 - loss: 1.1552 - val_accuracy: 0.5411 - val_loss: 1.3161
# Epoch 153/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5895 - loss: 1.1478 - val_accuracy: 0.5345 - val_loss: 1.3260
# Epoch 154/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5962 - loss: 1.1461 - val_accuracy: 0.5413 - val_loss: 1.3110
# Epoch 155/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5933 - loss: 1.1535 - val_accuracy: 0.5216 - val_loss: 1.3572
# Epoch 156/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5934 - loss: 1.1444 - val_accuracy: 0.5387 - val_loss: 1.3174
# Epoch 157/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5904 - loss: 1.1554 - val_accuracy: 0.5368 - val_loss: 1.3262
# Epoch 158/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5946 - loss: 1.1509 - val_accuracy: 0.5429 - val_loss: 1.3064
# Epoch 159/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5926 - loss: 1.1492 - val_accuracy: 0.5358 - val_loss: 1.3216
# Epoch 160/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5979 - loss: 1.1379 - val_accuracy: 0.5390 - val_loss: 1.3090
# Epoch 161/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5936 - loss: 1.1517 - val_accuracy: 0.5308 - val_loss: 1.3362
# Epoch 162/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5905 - loss: 1.1602 - val_accuracy: 0.5425 - val_loss: 1.3127
# Epoch 163/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5956 - loss: 1.1355 - val_accuracy: 0.5347 - val_loss: 1.3263
# Epoch 164/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5939 - loss: 1.1446 - val_accuracy: 0.5394 - val_loss: 1.3251
# Epoch 165/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5915 - loss: 1.1491 - val_accuracy: 0.5204 - val_loss: 1.3645
# Epoch 166/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5994 - loss: 1.1351 - val_accuracy: 0.5264 - val_loss: 1.3690
# Epoch 167/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5936 - loss: 1.1385 - val_accuracy: 0.5416 - val_loss: 1.3102
# Epoch 168/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5999 - loss: 1.1317 - val_accuracy: 0.5433 - val_loss: 1.2907
# Epoch 169/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5961 - loss: 1.1380 - val_accuracy: 0.5383 - val_loss: 1.3133
# Epoch 170/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6015 - loss: 1.1188 - val_accuracy: 0.5464 - val_loss: 1.3028
# Epoch 171/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - accuracy: 0.5973 - loss: 1.1304 - val_accuracy: 0.5473 - val_loss: 1.3010
# Epoch 172/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6012 - loss: 1.1285 - val_accuracy: 0.5328 - val_loss: 1.3413
# Epoch 173/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5965 - loss: 1.1294 - val_accuracy: 0.5462 - val_loss: 1.3089
# Epoch 174/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5947 - loss: 1.1345 - val_accuracy: 0.5454 - val_loss: 1.3030
# Epoch 175/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5963 - loss: 1.1329 - val_accuracy: 0.5365 - val_loss: 1.3165
# Epoch 176/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5974 - loss: 1.1325 - val_accuracy: 0.5434 - val_loss: 1.3144
# Epoch 177/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5991 - loss: 1.1283 - val_accuracy: 0.5244 - val_loss: 1.3732
# Epoch 178/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.5913 - loss: 1.1399 - val_accuracy: 0.5410 - val_loss: 1.3158
# Epoch 179/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6016 - loss: 1.1263 - val_accuracy: 0.5373 - val_loss: 1.3332
# Epoch 180/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5974 - loss: 1.1325 - val_accuracy: 0.5393 - val_loss: 1.3295
# Epoch 181/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6051 - loss: 1.1189 - val_accuracy: 0.5495 - val_loss: 1.2891
# Epoch 182/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6019 - loss: 1.1222 - val_accuracy: 0.5351 - val_loss: 1.3279
# Epoch 183/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6031 - loss: 1.1216 - val_accuracy: 0.5447 - val_loss: 1.3187
# Epoch 184/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6025 - loss: 1.1210 - val_accuracy: 0.5426 - val_loss: 1.3094
# Epoch 185/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6011 - loss: 1.1229 - val_accuracy: 0.5424 - val_loss: 1.3215
# Epoch 186/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6036 - loss: 1.1176 - val_accuracy: 0.5227 - val_loss: 1.3617
# Epoch 187/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6057 - loss: 1.1069 - val_accuracy: 0.5436 - val_loss: 1.3095
# Epoch 188/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6063 - loss: 1.1078 - val_accuracy: 0.5423 - val_loss: 1.3119
# Epoch 189/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6050 - loss: 1.1179 - val_accuracy: 0.5384 - val_loss: 1.3350
# Epoch 190/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6093 - loss: 1.1117 - val_accuracy: 0.5340 - val_loss: 1.3372
# Epoch 191/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6043 - loss: 1.1112 - val_accuracy: 0.5353 - val_loss: 1.3192
# Epoch 192/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6056 - loss: 1.1010 - val_accuracy: 0.5493 - val_loss: 1.3048
# Epoch 193/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6057 - loss: 1.1105 - val_accuracy: 0.5409 - val_loss: 1.3180
# Epoch 194/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6062 - loss: 1.1078 - val_accuracy: 0.5427 - val_loss: 1.3103
# Epoch 195/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6080 - loss: 1.1101 - val_accuracy: 0.5299 - val_loss: 1.3524
# Epoch 196/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6087 - loss: 1.0987 - val_accuracy: 0.5426 - val_loss: 1.3204
# Epoch 197/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6082 - loss: 1.1054 - val_accuracy: 0.5466 - val_loss: 1.2986
# Epoch 198/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6131 - loss: 1.0903 - val_accuracy: 0.5391 - val_loss: 1.3289
# Epoch 199/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6090 - loss: 1.0981 - val_accuracy: 0.5437 - val_loss: 1.3129
# Epoch 200/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6030 - loss: 1.1075 - val_accuracy: 0.5384 - val_loss: 1.3332

# %% [markdown]
# ### 6. Model evaluation

# %%
X_test = X_test.astype('float32') / 255.0
y_test_encoded = keras.utils.to_categorical(y_test, num_classes=10)

# %%
score = model.evaluate(X_test, y_test_encoded, verbose=0)
print('Test loss:', score[0])
print(f'Test accuracy: {score[1]*100} %')
# Out:
# Test loss: 1.3215248584747314
# Test accuracy: 53.769999742507935 %

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# As you can see from the evaluation above, we was able to achive approx. 30% of an accuracy. In other word approx. 70% of an images we classified wrongly. That is really bad!

# %% [markdown]
# Lets check the best predictions from our model:

# %%
def show_the_best_predictions(model, x_test: np.array, y_test: np.array, n_of_pred: int = 10) -> None:
  mapping = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

  predictions = model.predict(x_test)
  y_test = y_test.reshape(1,-1)
  predictions_ind = np.argmax(predictions, axis=1)
  predictions_ind = predictions_ind.reshape(1, -1)

  corect_predictions = np.where(predictions_ind == y_test)

  rows_correct = corect_predictions[1]
  predictedtions_correct = predictions[rows_correct]
  target_correct = y_test[0][rows_correct]

  max_samples = predictions[rows_correct, target_correct]
  selected_images = x_test[rows_correct]
  sorted_ind = np.argsort(max_samples)[::-1]


  images = []
  prob = []
  labels = []


  for ind in range(n_of_pred):

    index = sorted_ind[ind]

    labels.append(target_correct[index])
    prob.append(max_samples[index])
    images.append(selected_images[index])

  plt.figure(figsize=(20,10))
  
  images = np.concatenate(np.asarray(images),axis=1)
  plt.imshow(images)
  for ins in range(n_of_pred):
    texts = '{}: \n{:.3f} %'.format(mapping[labels[ins]], prob[ins]*100)
    plt.text((32/2) + 32*ins - len(mapping[labels[ins]]), 32*(5/4), texts)

  plt.axis('off')
  plt.show()

# %%
show_the_best_predictions(model, X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# ### Task Description:

# %% [markdown]
# You task of this exercise would be to improve the model's performance to achieve better results in image classification task. There is no need to change the preprocessing of the dataset. There are possible way how to improve the models performance:

# %% [markdown]
# 1. Hyperparameter tunning - change the hyperparameters so that the model will perform better. You can experiment with the following:
#  - *changing the number of neurons in the hidden layer*
#  - *changing the number of hidden layers*
#  - *changing the activation functions*
#  - *changing the learning rate*
#  - *changing the optimizer* - So far, we have used only Gradient descend as our optimizer, but Keras offers other algorithms that can perform better - check the documentation!
#  - *changing the number of learning epochs*\
#  - *changing the batch size*
#
# 2. Regularization techniques - There are several regularization techniques that can improve the model's performance:
#  - *Dropout* -  In the Keras lib. you can add *dropout layer* into your Sequential model using the following command  *model.add(Dropout(p))* where *p* is an hyperparameter that controls dropout probabily, typical values are 0.1 - 0.5.
#  - *L1, L2 regularization* - In keras the regularization is applied for selected layers, there is an example how to add l2 regularization to an layer (for more details check the documnetation):  *model.add(Dense(64, activation='relu', input_dim=100, kernel_regularizer=l2(0.01)))*
#  - *Early stopping* -  In Keras, you can use the EarlyStopping callback to implement early stopping in your model. *early_stopping = EarlyStopping(monitor='val_loss', patience=3)*,  *model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), callbacks=[early_stopping])*

# %% [markdown]
# Try to make the highest testing accuracy possible. You can directly edit the code that is presented above, or you can copy everything into new cells. Please submit only the code with the best performance and briefly describe what approaches you have tried and what were the results

# %% [markdown]
# ### WRITE YOUR DESCRIPTION IN THIS CELL ###

# %% [markdown]
# ### Voluntary task:
# Implement one of the hyperparameter tunning algorithms discussed in the lecture, such as *Grid Search*, *Random Search* or more sophisticated ones. Some of these algorithms are already included in the Keras. Check the documentation
